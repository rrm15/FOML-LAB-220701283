# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("datasets/age_height_dataset.csv")

x=df.iloc[:,0:1].values
y=df.iloc[:,1].values

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=0)

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)

plt.scatter(X_train,Y_train,color="green")
plt.plot(X_train,model.predict(X_train),color="blue")
plt.title("Linear Regression")
plt.xlabel("age")
plt.ylabel("height")
plt.show()

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(X_train)

poly_model=LinearRegression()
poly_model.fit(X_poly,Y_train)

X_values=np.linspace(min(x),max(x),100).reshape(-1,1)
X_values_poly=poly.transform(X_values)
Y_pred=poly_model.predict(X_values_poly)
plt.scatter(x,y,color="green")
plt.plot(X_values,Y_pred,color="blue")
plt.show()
